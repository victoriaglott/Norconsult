# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import cross_val_score, train_test_split
import re
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn import ensemble
from sklearn import datasets
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error

# %%
import tensorflow as tf

# %%
import numpy as np

# %%
df_raw = pd.read_csv("/Users/eier/Documents/Norconsult/TrainAndValid.csv", parse_dates = ['saledate'], low_memory = False)

# %% [markdown]
# ### Percentage data in dataset

# %%
df_available_raw = 1-df_raw.isnull().sum()/len(df_raw)
df = df_raw.replace(['None or Unspecified', '#NAME?', 'Unspecified', ' ', 'None'], np.nan)
data_available = (1-df.isnull().sum()/len(df))

# %%
# Out:
# 0          WL
# 1          WL
# 2         SSL
# 3         TEX
# 4         SSL
#          ...
# 412693    TEX
# 412694    TEX
# 412695    TEX
# 412696    TEX
# 412697    TEX
# Name: ProductGroup, Length: 412698, dtype: object

# %%
data_available.sort_values()
# Out:
# Backhoe_Mounting            0.000048
# Blade_Extension             0.001398
# Grouser_Tracks              0.007403
# Coupler_System              0.007868
# Enclosure_Type              0.008515
# Turbocharged                0.009656
# Pushblock                   0.014456
# Pad_Type                    0.021083
# Tip_Control                 0.022174
# Pattern_Changer             0.022624
# Travel_Controls             0.025273
# Scarifier                   0.031406
# Forks                       0.035508
# Blade_Width                 0.039889
# Thumb                       0.041818
# Undercarriage_Pad_Width     0.049605
# Stick_Length                0.050211
# Ripper                      0.052193
# Engine_Horsepower           0.062959
# Coupler                     0.073250
# Hydraulics_Flow             0.108670
# Tire_Size                   0.120706
# fiModelSeries               0.141154
# Blade_Type                  0.169698
# Steering_Controls           0.173303
# ...

# %% [markdown]
# ### Sort based on missing values

# %%
ignored_features = []
kept_features  = []
for feature in df.columns:
    if data_available[feature] < 0.7:
        ignored_features.append(feature)
    else:
        kept_features.append(feature)

# %%
ignored_features = ["SalesID", 
                    "datasource", 
                    'fiModelDesc', #Bare en cocatination
                    
    

                     'MachineHoursCurrentMeter',
                     'UsageBand',
                     'fiProductClassDesc',# her må du kanskje splitte
                     #'fiSecondaryDesc',
                     #'fiModelSeries',
                     #'fiModelDescriptor',
                     #'ProductSize',
                     'Drive_System',
                     'Forks',
                     'Pad_Type',
                     'Ride_Control',
                     'Stick',
                     #'Transmission',
                     'Turbocharged',
                     'Blade_Extension',
                     'Blade_Width',
                     'Enclosure_Type',
                     'Engine_Horsepower',
                     'Pushblock',
                     'Ripper',
                     'Scarifier',
                     'Tip_Control',
                     #'Tire_Size',
                     'Coupler',
                     'Coupler_System',
                     'Grouser_Tracks',
                     'Hydraulics_Flow',
                     'Track_Type',
                     'Undercarriage_Pad_Width',
                     'Stick_Length',
                     'Thumb',
                     'Pattern_Changer',
                     'Grouser_Type',
                     'Backhoe_Mounting',
                     'Blade_Type',
                     'Travel_Controls',
                     'Differential_Type',
                     'Steering_Controls',
                     'SalesID',
                     'datasource',
                     'SalesID',
                     'datasource',
                     'fiModelDesc']

# %%
df["auctioneerID"] = df['auctioneerID'].fillna(df["auctioneerID"].value_counts().index[0])

x = df.drop(columns = ignored_features)
x = x.drop(columns = ["SalePrice"])
y = df["SalePrice"]

# %%
x.columns
# Out:
# Index(['MachineID', 'ModelID', 'auctioneerID', 'YearMade', 'saledate',
#        'fiBaseModel', 'fiSecondaryDesc', 'fiModelSeries', 'fiModelDescriptor',
#        'ProductSize', 'state', 'ProductGroup', 'ProductGroupDesc', 'Enclosure',
#        'Transmission', 'Hydraulics', 'Tire_Size'],
#       dtype='object')

# %%
#Change format of saledate

# %%
x["saledate"] = x["saledate"].astype(str)
x_date = x["saledate"].str.split("-",n = 3, expand = True)
x_date
x["SaleYear"] = x_date[0].astype(int)
x["SaleMonth"] = x_date[1].astype(int)
x["SaleDay"] = x_date[2].astype(int)
x = x.drop(columns = ["saledate"])

# %%
min(x["YearMade"])
# Out:
# 1000

# %%
x.loc[df.YearMade<1950, 'YearMade'] = np.nan

# %%
x["YearMade"] = x['YearMade'].fillna(df["YearMade"].median())

# %%
x["YearsOld"] = x["SaleYear"] - x["YearMade"] + x['SaleMonth']/12

# %%
x['Tire_Size'] = x['Tire_Size'].str.replace(r'\D+','')
x['Tire_Size'] = x['Tire_Size'].replace('', np.nan)
x["Tire_Size"] = x["Tire_Size"].astype(float)

# %%
x["ProductSize"] = x["ProductSize"].fillna('PS_nan')

# %%
x['Transmission'] = x['Transmission'].fillna('T_nan')

# %%
#Split into numerical and categorical features

# %%
x_numerical = x.select_dtypes(['number'])

# %%
x_categorical = x.select_dtypes(['object'])

# %%
1-x_categorical.isnull().sum()/len(x_categorical)
# Out:
# fiBaseModel          1.000000
# fiSecondaryDesc      0.658973
# fiModelSeries        0.141154
# fiModelDescriptor    0.181285
# ProductSize          1.000000
# state                0.993213
# ProductGroup         1.000000
# ProductGroupDesc     1.000000
# Enclosure            0.999186
# Transmission         1.000000
# Hydraulics           0.799914
# dtype: float64

# %%
#x_numerical = x_numerical.replace({'YearMade': np.nan}, x_numerical['YearMade'].mean() )

# %%
x_categorical_imputed = x_categorical.apply(lambda x: x.fillna(x.value_counts().index[0]))

# %%
(1-x_numerical.isnull().sum()/len(x_numerical))
# Out:
# MachineID       1.0
# ModelID         1.0
# auctioneerID    1.0
# YearMade        1.0
# SaleYear        1.0
# SaleMonth       1.0
# SaleDay         1.0
# YearsOld        1.0
# dtype: float64

# %%
(1-x_categorical_imputed.isnull().sum()/len(x_categorical_imputed))
# Out:
# fiBaseModel           1.0
# fiProductClassDesc    1.0
# state                 1.0
# ProductGroup          1.0
# ProductGroupDesc      1.0
# Enclosure             1.0
# Hydraulics            1.0
# dtype: float64

# %%
x_categorical_imputed = pd.get_dummies(x_categorical_imputed, prefix_sep='_', drop_first=True)

# %%
x = pd.concat([x_numerical, x_categorical_imputed], axis = 1)

# %% [markdown]
# ## Random forest

# %%
#x["YearsOld"] = x["saleyear"] - x["YearMade"]

# %%
x_numerical.columns
# Out:
# Index(['MachineID', 'ModelID', 'auctioneerID', 'YearMade', 'SaleYear',
#        'SaleMonth', 'SaleDay', 'YearsOld'],
#       dtype='object')

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=17)

# %%
rf = RandomForestRegressor(n_estimators = 10, random_state = 17)

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=17, verbose=0,
#                       warm_start=False)

# %%
predictions = rf.predict(x_val)

# %%
def rsmle(train,predictions):
    return np.sqrt(np.mean(pow(np.log(predictions+1) - np.log(train+1),2)))

# %%
rsmle(y_val.values, predictions)
# Out:
# 0.23189312077305618

# %%
sale_map_rf = dict(zip(y_val, predictions))
sale_map_rf
# Out:
# {9250.0: 9225.0,
#  19000.0: 15600.0,
#  26000.0: 24550.0,
#  50000.0: 44200.0,
#  47000.0: 56200.0,
#  74000.0: 67600.0,
#  22000.0: 24575.0,
#  22500.0: 22475.0,
#  13000.0: 14660.0,
#  47500.0: 47100.0,
#  18500.0: 15850.0,
#  97000.0: 84850.0,
#  56000.0: 71650.0,
#  14500.0: 16650.0,
#  14000.0: 14850.0,
#  13500.0: 21175.0,
#  12000.0: 11350.0,
#  8500.0: 12050.0,
#  34000.0: 26350.0,
#  57000.0: 59450.0,
#  80000.0: 85050.0,
#  32500.0: 27500.0,
#  27750.0: 26050.0,
#  46000.0: 48500.0,
#  27000.0: 35150.0,
#  120000.0: 89600.0,
#  45000.0: 61450.0,
#  17000.0: 19900.0,
#  42500.0: 38300.0,
#  52000.0: 42750.0,
#  21000.0: 28100.0,
#  25000.0: 25950.0,
#  25500.0: 27800.0,
#  60000.0: 74250.0,
#  34500.0: 41700.0,
#  16000.0: 29200.0,
#  36000.0: 44100.0,
#  8000.0: 9500.0,
#  77500.0: 69750.0,
#  35000.0: 38500.0,
#  57500.0: 52600.0,
#  15000.0: 25600.0,
#  51000.0: 51650.0,
#  48000.0: 47250.0,
#  20000.0: 20195.0,
#  11500.0: 10800.0,
#  37000.0: 40200.0,
# ...

# %%
import collections

# %%
sale_map_rf = collections.OrderedDict(sorted(sale_map_rf.items()))

# %%
plt.plot(list(sale_map_rf.values()))
plt.plot(list(sale_map_rf.keys()))

# %%
x_numerical.columns
# Out:
# Index(['MachineID', 'ModelID', 'auctioneerID', 'YearMade', 'SaleYear',
#        'SaleMonth', 'SaleDay', 'YearsOld'],
#       dtype='object')

# %%
importances = list(rf.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 4)) for feature, importance in zip(x_train.columns, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: Enclosure_EROPS w AC Importance: 0.2247
# Variable: YearsOld             Importance: 0.1212
# Variable: ModelID              Importance: 0.1121
# Variable: YearMade             Importance: 0.0557
# Variable: fiProductClassDesc_Backhoe Loader - 14.0 to 15.0 Ft Standard Digging Depth Importance: 0.0383
# Variable: ProductGroupDesc_Skid Steer Loaders Importance: 0.0349
# Variable: ProductGroup_SSL     Importance: 0.0267
# Variable: MachineID            Importance: 0.0256
# Variable: SaleYear             Importance: 0.0247
# Variable: ProductGroup_MG      Importance: 0.0233
# Variable: fiBaseModel_D6       Importance: 0.0213
# Variable: ProductGroupDesc_Motor Graders Importance: 0.02
# Variable: fiProductClassDesc_Track Type Tractor, Dozer - 260.0 + Horsepower Importance: 0.0173
# Variable: SaleDay              Importance: 0.0127
# Variable: fiProductClassDesc_Track Type Tractor, Dozer - 20.0 to 75.0 Horsepower Importance: 0.0121
# ...

# %% [markdown]
# ## Neural net

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaler.fit(x)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x = scaler.transform(x)

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=17)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten(input_shape = [len(x_train.columns)]))
model.add(tf.keras.layers.Dense(20, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(20, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(1))
model.compile(optimizer=tf.keras.optimizers.RMSprop(0.01),
          loss='mse',
          metrics=['mse'])

model.fit(x_train, y_train, epochs = 20)#, batch_size=7)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 330158 samples
# Epoch 1/20
# 330158/330158 [==============================] - 9s 28us/sample - loss: 590187037.0759 - mse: 590182848.0000
# Epoch 2/20
# 330158/330158 [==============================] - 9s 27us/sample - loss: 488489488.2197 - mse: 488464256.0000
# Epoch 3/20
# 330158/330158 [==============================] - 9s 27us/sample - loss: 473836455.4241 - mse: 473778624.0000
# Epoch 4/20
# 330158/330158 [==============================] - 9s 27us/sample - loss: 468859534.9425 - mse: 468748032.0000
# Epoch 5/20
# 330158/330158 [==============================] - 9s 28us/sample - loss: 466449196.3157 - mse: 466274880.00000s - loss: 466330052.7662 - mse: 466156192.
# Epoch 6/20
# 330158/330158 [==============================] - 9s 28us/sample - loss: 464678400.8591 - mse: 464434176.0000
# Epoch 7/20
# ...

# %%
y_train.values
# Out:
# array([45000.,  5750., 25000., ..., 35000., 32000., 64000.])

# %%
predictions = model.predict(x_train.values)
predictions
# Out:
# array([[26809.758],
#        [33437.63 ],
#        [26557.438],
#        ...,
#        [41923.324],
#        [37836.97 ],
#        [56135.266]], dtype=float32)

# %%
preds = []
for i in range(len(predictions)):
    preds.append(predictions[i][0])

# %%
mse = ((np.array(y_train.values)-np.array(preds))**2).mean()

# %%
mse
# Out:
# 441555572.29977494

# %%
sale_map = dict(zip(y_val, preds))

# %%
import collections

# %%
sale_map = collections.OrderedDict(sorted(sale_map.items()))

# %%
plt.plot(list(sale_map.values()))
plt.plot(list(sale_map.keys()))

# %%
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=20,
#                       n_jobs=None, oob_score=False, random_state=17, verbose=0,
#                       warm_start=False)

# %%
errors = abs(predictions - y_val)

# %%
importances = list(rf.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(x_train.columns, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: ModelID              Importance: 0.22
# Variable: YearMade             Importance: 0.17
# Variable: ProductGroupDesc_Skid Steer Loaders Importance: 0.1
# Variable: saleyear             Importance: 0.09
# Variable: MachineID            Importance: 0.07
# Variable: fiProductClassDesc_Backhoe Loader - 14.0 to 15.0 Ft Standard Digging Depth Importance: 0.03
# Variable: ProductGroupDesc_Motor Graders Importance: 0.03
# Variable: salemonth            Importance: 0.02
# Variable: saleday              Importance: 0.02
# Variable: fiProductClassDesc_Track Type Tractor, Dozer - 20.0 to 75.0 Horsepower Importance: 0.02
# Variable: fiProductClassDesc_Track Type Tractor, Dozer - 260.0 + Horsepower Importance: 0.02
# Variable: ProductGroupDesc_Wheel Loader Importance: 0.02
# Variable: fiProductClassDesc_Hydraulic Excavator, Track - 0.0 to 2.0 Metric Tons Importance: 0.01
# Variable: fiProductClassDesc_Hydraulic Excavator, Track - 2.0 to 3.0 Metric Tons Importance: 0.01
# ...

# %%
#state sold: ikke noe Importance: 0.0
#mest viktig: modelID, YearMade, ProductGroupDesc_Skid, MachineID, salemonth, saleday

# %%
#fiBaseModel droppe denne?
